# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ObesityDataSet_raw_and_data_sinthetic.csv")
df
data = df.copy()
data
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
data["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
df.head()
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# 0                            yes  0.0  1.0  Sometimes  Public_Transportation
# 1                            yes  3.0  0.0  Sometimes  Public_Transportation
# 2                            yes  2.0  1.0  Sometimes  Public_Transportation
# 3                             no  2.0  0.0  Sometimes                Walking
# 4                             no  0.0  0.0  Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
df["Weight"].mean()
# Out:
# 86.58605812648035

# %%
df["Weight"].std()
# Out:
# 26.191171745204688

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

gender_counts = df["Gender"].value_counts()
total = df["Gender"].sum()
plt.figure(figsize=(4, 8))
plt.pie(gender_counts, labels=gender_counts.index, startangle=180)
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.title("Pie chart of Gender Distribution")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(x = df["Age"] ,y =  df["Weight"] ,  )
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Line graph of Age vs. Weight (First 5 data points)")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(df["Age"], df["Weight"])
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Bar plot of Age vs. Weight")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df["Age"].head(10))
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")

plt.subplot(1, 2, 2)
plt.hist(df["Weight"].head(10))
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.title("Histogram of Weight")

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight', 'CALC', 'FAVC', 'FCVC', 'NCP',
#        'SCC', 'SMOKE', 'CH2O', 'family_history_with_overweight', 'FAF', 'TUE',
#        'CAEC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.groupby("Gender").agg({"Height":"std","Weight":"mean"})
# Out:
#           Height     Weight
# Gender
# Female  0.074509  82.302364
# Male    0.072174  90.769478

# %%
data = df.copy()
data
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
for i in data:
    if(data.dtypes[i] == float):
        print(i)
# Out:
# Age
# Height
# Weight
# FCVC
# NCP
# CH2O
# FAF
# TUE

# %%
import seaborn as sb
import matplotlib.pyplot as plt
for i in data:
    if (data[i].dtypes == float):
        print(i,": ",data[i].median())
        print(i,": ",data[i].mean())
        
sb.boxplot(data["Weight"])
plt.title("Weight")
# Out:
# Age :  22.77789
# Age :  24.312599908574136
# Height :  1.700499
# Height :  1.7016773533870204
# Weight :  83.0
# Weight :  86.58605812648035
# FCVC :  2.385502
# FCVC :  2.4190430615821885
# NCP :  3.0
# NCP :  2.6856280497394596
# CH2O :  2.0
# CH2O :  2.0080114040738986
# FAF :  1.0
# FAF :  1.0102976958787304
# TUE :  0.62535
# TUE :  0.657865923732828
# Text(0.5, 1.0, 'Weight')

# %%
selected_columns = data[["CALC", "FAVC", "FCVC", "NCP", "SCC", "SMOKE"]]

# Create box plot
sb.boxplot(data=selected_columns)
# Out:
# <Axes: >

# %%
val = data.groupby('Gender')['Height'].sum()
print(plt.bar(val.index,val.values))
# Out:
# <BarContainer object of 2 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'Height': [175, 160, 165, 180, 155, 170]
})

# Calculate the sum of heights for each gender
sum_height_per_gender = data.groupby('Gender')['Height'].mean()

# Plot the bar plot
plt.figure(figsize=(10, 6))
plt.bar(sum_height_per_gender.index, sum_height_per_gender, color='skyblue',label = "Gender")
plt.legend()
plt.xlabel('Gender')
plt.ylabel('Total Height')
plt.title('Total Height by Gender')
plt.show()

# %%
data
# Out:
#    Gender  Height
# 0    Male     175
# 1  Female     160
# 2  Female     165
# 3    Male     180
# 4  Female     155
# 5    Male     170

# %%
data["NObeyesdad"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NObeyesdad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data["NObeyesdad"].unique()
#
# ...

# %%
data["NObeyesdad"].describe()

# %%
for i in data.columns:
    if(df[i].dtypes == 'float64'):
        sns.boxplot(x = df[i])
        plt.title(i)
        plt.show()
        print(i)

# %%
df["Age"].describe()

# %%
data

# %%
high = data["Age"].quantile(0.75)
low= data["Age"].quantile(0.25)
print(high,low)
IQR = high - low
upper = high  +1.5*IQR
lower = low  - 1.5*IQR
print(upper,lower)

# %%
def limit(value):
    if value > upper:
        return upper
    elif value < lower:
        return lower
    else:
        return value

# %%
data["Age"] = data["Age"].apply(limit)

# %%
data["Age"].describe()

# %%
print(sns.boxplot(x = data["Age"]),plt.title("Age"))# so the crt value without the outlier

# %%
data["Height"].corr(data["Weight"])

# %%
data.corr()

# %%
data["MTRANS"].value_counts()

# %%
data.groupby("MTRANS")["Weight"].sum().plot(kind = "pie",autopct='%1.1f%%')

# %%
data.groupby("NObeyesdad")["Weight"].mean().plot(kind = "bar")

# %%
data["NObeyesdad"].value_counts()

# %%
li = []
for i in data.columns:
    li.append(i.replace("_"," "))    
data.columns = li
data

# %%
data = pd.get_dummies(data,columns = ["Gender"],drop_first = True)
data.head(10)

# %%
data = pd.get_dummies(data,columns = ["CALC","FAVC","SCC","SMOKE","family_history_with_overweight","CAEC","MTRANS","NObeyesdad"],drop_first = True)
data.head(10)

# %% [markdown]
# # load this data

# %%
for i in data:
    if len(i) >=7:
        data[i] = data[i].astype(int)

data
# Out:
#    Gender  Height
# 0    Male     175
# 1  Female     160
# 2  Female     165
# 3    Male     180
# 4  Female     155
# 5    Male     170

# %%
data
# Out:
#    Gender  Height
# 0    Male     175
# 1  Female     160
# 2  Female     165
# 3    Male     180
# 4  Female     155
# 5    Male     170

# %%
print(data.iloc[0:1,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(data.iloc[0:1,3])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# ...

# %%
data
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
dep = data.iloc[:,10]
y = data.iloc[:,0:10]
z = data.iloc[:,11:]
indep = pd.concat([y,z], axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(dep,indep, test_size = 0.3)

# %%
x_train
# Out:
# 584     1.426874
# 753     1.825629
# 1       3.000000
# 391     2.000000
# 1942    2.555189
#           ...
# 1449    2.000000
# 843     2.081121
# 465     1.000000
# 113     2.000000
# 1729    1.336526
# Name: CH2O, Length: 1477, dtype: float64

# %%
x_test
# Out:
# 228     3.000000
# 985     2.000000
# 575     1.000000
# 328     3.000000
# 714     1.596212
#           ...
# 774     1.530046
# 1971    2.699675
# 1677    2.660290
# 643     2.891713
# 159     2.000000
# Name: CH2O, Length: 634, dtype: float64

# %%
y_train
# Out:
#             Age  Gender    Height      Weight       CALC FAVC      FCVC  \
# 584   23.000000  Female  1.717601   51.073918         no  yes  2.000000
# 753   21.962426    Male  1.696336   75.000000  Sometimes  yes  2.000000
# 1     21.000000  Female  1.520000   56.000000  Sometimes   no  3.000000
# 391   18.000000  Female  1.700000   50.000000  Sometimes   no  2.000000
# 1942  26.000000  Female  1.600905  110.074946  Sometimes  yes  3.000000
# ...         ...     ...       ...         ...        ...  ...       ...
# 1449  23.099906  Female  1.571812   78.997166         no  yes  2.000000
# 843   21.652229    Male  1.700181   75.057177  Sometimes  yes  2.086093
# 465   18.000000  Female  1.600000   51.000000  Sometimes  yes  2.000000
# 113   22.000000  Female  1.500000   49.000000         no   no  2.000000
# 1729  29.669219    Male  1.909188  129.194490  Sometimes  yes  2.432355
#
#            NCP  SCC SMOKE family_history_with_overweight       FAF       TUE  \
# ...

# %%
y_test
# Out:
#             Age  Gender    Height      Weight        CALC FAVC      FCVC  \
# 228   40.000000  Female  1.680000   80.000000          no   no  3.000000
# 985   22.591439    Male  1.650000   80.000000          no  yes  2.000000
# 575   17.767432  Female  1.743790   50.000000   Sometimes  yes  1.344854
# 328   19.000000    Male  1.740000   74.000000   Sometimes   no  3.000000
# 714   19.349258  Female  1.523370   42.000000   Sometimes  yes  2.913486
# ...         ...     ...       ...         ...         ...  ...       ...
# 774   21.000000  Female  1.754813   77.929204   Sometimes  yes  2.915279
# 1971  19.297004  Female  1.817271  141.917802   Sometimes  yes  3.000000
# 1677  30.108216    Male  1.841908  124.070717   Sometimes  yes  2.467548
# 643   19.962470    Male  1.756338   54.982340          no  yes  2.277436
# 159   27.000000    Male  1.640000   78.000000  Frequently  yes  2.000000
#
#            NCP SCC SMOKE family_history_with_overweight       FAF       TUE  \
# ...

# %%
from sklearn import preprocessing
scale = preprocessing.StandardScaler()

# %%
y_train = scale.fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9668\4048366999.py in ?()
# ----> 1 y_train = scale.fit_transform(y_train)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
def hello(n):
    return n
    
hello("Print")

print("hello")
hello("print")
# Out:
# hello
# 'print'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(0)
x = np.random.rand(100, 1) * 10  # 100 random numbers between 0 and 10
y = 2 * x + 1 + np.random.randn(100, 1)  # Linear relationship with some noise

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Dataset')
plt.show()

# %%
# Transform features into polynomial features
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

# Fit the polynomial regression model
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)
y_poly_pred = poly_reg.predict(x_poly)

# %%
# Fit the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(x, y)
y_lin_pred = lin_reg.predict(x)

# Calculate mean squared error
lin_mse = mean_squared_error(y, y_lin_pred)
poly_mse = mean_squared_error(y, y_poly_pred)

print(f'Linear Regression MSE: {lin_mse}')
print(f'Polynomial Regression MSE: {poly_mse}')

# Plot both models
plt.scatter(x, y, label='Data')
plt.plot(x, y_lin_pred, color='blue', label='Linear Regression')
plt.plot(x, y_poly_pred, color='red', linestyle='--', label='Polynomial Regression (degree=2)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear vs Polynomial Regression')
plt.legend()
plt.show()
# Out:
# Linear Regression MSE: 0.9924386487246483
# Polynomial Regression MSE: 0.9735576723414217
